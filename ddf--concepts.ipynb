# %%
import pandas as pd

# %%
data = pd.read_csv(
    "ddf--concepts.csv", low_memory=False
)

# %%
data
# Out:
#                                                concept  \
# 0                    adults_with_hiv_percent_age_15_49
# 1                            age_at_1st_marriage_women
# 2                   aged_15_24_employment_rate_percent
# 3                 aged_15_24_unemployment_rate_percent
# 4    aged_15_64_labour_force_participation_rate_per...
# 5                  aged_15plus_employment_rate_percent
# 6    aged_15plus_labour_force_participation_rate_pe...
# 7                aged_15plus_unemployment_rate_percent
# 8    aged_25_54_labour_force_participation_rate_per...
# 9                 aged_25_54_unemployment_rate_percent
# 10                aged_55_64_unemployment_rate_percent
# 11   aged_65plus_labour_force_participation_rate_pe...
# 12               aged_65plus_unemployment_rate_percent
# 13              agricultural_land_percent_of_land_area
# 14      agricultural_water_withdrawal_percent_of_total
# 15                          agriculture_percent_of_gdp
# ...

# %%
list(data[['concept', 'drill_up']].dropna()['drill_up'])
# Out:
# ['["world_6region", "income_groups", "landlocked", "g77_and_oecd_countries", "main_religion_2008", "world_4region"]']

# %%
data[data['concept']=='country']
# Out:
#      concept color concept_type description description_long domain  \
# 121  country   NaN   entity_set         NaN              NaN    geo
#
#                                               drill_up  \
# 121  ["world_6region", "income_groups", "landlocked...
#
#                                          indicator_url     name name_catalog  \
# 121  https://github.com/open-numbers/ddf--gapminder...  Country          NaN
#
#     name_short scales source source_long source_url             tags
# 121        NaN    NaN    NaN         NaN        NaN  categorizations
