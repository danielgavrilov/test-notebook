# %%
import requests
import pandas as pd

# %%
metadata_groups = requests.get("http://fenixservices.fao.org/faostat/api/v1/en/groupsanddomains?section=download").json()['data']

# %% [markdown]
# This basically gets the datasets for which there is metadata from the API (there isn't for all!). Just using pandas to display it nicely:

# %%
pd.DataFrame(metadata_groups)
# Out:
#    date_update domain_code                                        domain_name  \
# 0   2019-01-18          QC                                              Crops
# 1   2017-05-17          QD                                    Crops processed
# 2   2018-12-20          QA                                       Live Animals
# 3   2019-02-26          QL                                  Livestock Primary
# 4   2017-05-17          QP                                Livestock Processed
# 5   2018-05-22          QI                                 Production Indices
# 6   2018-11-30          QV                   Value of Agricultural Production
# 7   2019-10-09          TP                       Crops and livestock products
# 8   2019-10-09          TA                                       Live animals
# 9   2019-10-09          TM                              Detailed trade matrix
# 10  2019-10-09          TI                                      Trade Indices
# ...

# %% [markdown]
# Get in-depth metadata for each dataset:

# %%
def getMetadata(domain_code):
    url = "http://fenixservices.fao.org/faostat/api/v1/en/metadata/%s" % domain_code
    return requests.get(url).json()['data']

# %%
metadata_by_name = { group['domain_name']: getMetadata(group['domain_code']) for group in metadata_groups }

# %%
metadata_by_name
# Out:
# {'Crops': [{'domain_code': 'QC',
#    'metadata_group_code': '1',
#    'metadata_group_label': 'Contacts',
#    'metadata_code': '1.1',
#    'metadata_label': 'Contact organisation',
#    'metadata_text': 'Food and Agriculture Organization of the United Nations (FAO)',
#    'ord': 110},
#   {'domain_code': 'QC',
#    'metadata_group_code': '1',
#    'metadata_group_label': 'Contacts',
#    'metadata_code': '1.2',
#    'metadata_label': 'Contact organisation unit',
#    'metadata_text': 'Statistics Division (ESS)',
#    'ord': 120},
#   {'domain_code': 'QC',
#    'metadata_group_code': '1',
#    'metadata_group_label': 'Contacts',
#    'metadata_code': '1.3',
#    'metadata_label': 'Contact name',
#    'metadata_text': 'Mr. Salar Tayyib',
#    'ord': 130},
#   {'domain_code': 'QC',
#    'metadata_group_code': '1',
#    'metadata_group_label': 'Contacts',
#    'metadata_code': '1.4',
#    'metadata_label': 'Contact person function',
# ...

# %%
metadata_by_name["Food Balance Sheets"]
# Out:
# [{'domain_code': 'FBS',
#   'metadata_group_code': '1',
#   'metadata_group_label': 'Contacts',
#   'metadata_code': '1.1',
#   'metadata_label': 'Contact organisation',
#   'metadata_text': 'Food and Agriculture Organization of the United Nations (FAO)',
#   'ord': 110},
#  {'domain_code': 'FBS',
#   'metadata_group_code': '1',
#   'metadata_group_label': 'Contacts',
#   'metadata_code': '1.2',
#   'metadata_label': 'Contact organisation unit',
#   'metadata_text': 'Statistics Division (ESS)',
#   'ord': 120},
#  {'domain_code': 'FBS',
#   'metadata_group_code': '1',
#   'metadata_group_label': 'Contacts',
#   'metadata_code': '1.3',
#   'metadata_label': 'Contact name',
#   'metadata_text': 'Mr. Salar Tayyib',
#   'ord': 130},
#  {'domain_code': 'FBS',
#   'metadata_group_code': '1',
#   'metadata_group_label': 'Contacts',
#   'metadata_code': '1.4',
#   'metadata_label': 'Contact person function',
#   'metadata_text': 'Team Leader/SUA-FBS Officer',
#   'ord': 140},
# ...

# %%
def find(fn, lst):
    for item in lst:
        if fn(item):
            return item

# %%
def get_add_info(metadata):
    return find(lambda row: row['metadata_label'] == 'Statistical concepts and definitions', metadata)

def get_pub_source(metadata):
    return find(lambda row: row['metadata_label'] == 'Source data', metadata)

# %%
get_add_info(metadata_by_name["Food Balance Sheets"])
# Out:
# {'domain_code': 'FBS',
#  'metadata_group_code': '3',
#  'metadata_group_label': 'Main Characteristics data',
#  'metadata_code': '3.4',
#  'metadata_label': 'Statistical concepts and definitions',
# ...

# %%
get_pub_source(metadata_by_name["Food Balance Sheets"])
# Out:
# {'domain_code': 'FBS',
#  'metadata_group_code': '20',
#  'metadata_group_label': 'Identification Data',
#  'metadata_code': '20.1',
#  'metadata_label': 'Source data',
#  'metadata_text': 'The main source is official statistics from FAO member countries.  Exceptionally, unofficial data are also used as well as estimated/imputed data.  In both cases this is "flagged".  Data are recorded as countries report them, except for eliminating obvious errors.  The source data can originate from surveys, administrative data and estimates based on expert observations.  Which type of source is used by countries affect significantly reliability and comparability of data.',
#  'ord': 2010}
